# %% [markdown]
# Plot y versus x as lines and/or markers.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Example dataset: Value in dolars of different currencies in 2017

# %%
df = pd.read_csv("datasets/currencies.csv", index_col=0)

# %%
df.head()
# Out:
#          ARS       BRL         CLP          COP    CRC     EUR        MXN  \
# 0  15.870000  3.253090  670.555891  3002.000000  553.1  0.9508  20.730000
# 1  15.873015  3.253074  670.560000  3002.010000  553.1  0.9508  20.730000
# 2  15.850000  3.265839  670.690812  3001.000000  553.1  0.9565  20.733983
# 3  15.948963  3.265000  675.173829  2981.514609  553.1  0.9611  21.110407
# 4  16.080000  3.220000  671.366230  2970.355849  553.1  0.9534  21.450022
#
#         PEN        date
# 0  3.355998  2017-01-01
# 1  3.356000  2017-01-02
# 2  3.360994  2017-01-03
# 3  3.392602  2017-01-04
# 4  3.389497  2017-01-05

# %% [markdown]
# Plot the value in dolars of the Peruvian sol (PEN) in 2017

# %%
#change plot size
plt.figure(figsize=(20,6))
# Converting to datetime is very important
plt.plot(pd.to_datetime(df.date), df.PEN)
